# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
partner= pd.read_csv ("partnerB.csv")
referral = pd.read_csv("referralB.csv")
sales = pd.read_csv("sales_people.csv")

# %%
sales
# Out:
#       name    country
# 0   Orange  Singapore
# 1    Apple  Singapore
# 2     Lion   HongKong
# 3     Tree   HongKong
# 4     Root   HongKong
# 5      Sky   HongKong
# 6    Cloud         UK
# 7    Horiz         UK
# 8     Leaf         UK
# 9    Daisy         UK
# 10   Tulip         UK
# 11     Fig         UK

# %%
join= pd.concat([partner,referral,sales], axis =1, join="outer")

# %%
join
# Out:
#        id partner_type lead_sales_contact created_date updated_date    id  \
# 0     2.0        Agent             Potato   2020-08-31   2020-12-04     1
# 1     3.0        Agent               Lion   2020-08-31   2021-04-20     2
# 2     4.0        Agent             Potato   2020-08-31   2021-03-25     3
# 3     5.0        Agent               Lion   2020-08-31   2020-12-07     4
# 4     6.0        Agent             Potato   2020-08-31   2021-01-04     5
# ...   ...          ...                ...          ...          ...   ...
# 1465  NaN          NaN                NaN          NaN          NaN  1466
# 1466  NaN          NaN                NaN          NaN          NaN  1467
# 1467  NaN          NaN                NaN          NaN          NaN  1468
# 1468  NaN          NaN                NaN          NaN          NaN  1469
# 1469  NaN          NaN                NaN          NaN          NaN  1470
#
#       company_id  partner_id  consultant_id      status  is_outbound  \
# ...

# %%
join.to_csv('joinDatasets.csv',index=False)
